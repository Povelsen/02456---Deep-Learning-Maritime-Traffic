# %%
import pandas as pd
import glob

# Automatically pick one .parquet file from your output folder
path = glob.glob("output/*/*/*.parquet")[0]  # first file
print(f"📄 Loading: {path}")

# Load data into a dataframe
df = pd.read_parquet(path)

# Show summary
print(f"\n✅ Loaded {len(df)} rows and {len(df.columns)} columns\n")
print(df.head())


import pandas as pd

df_all = pd.read_parquet("output/")
print(len(df_all), "rows loaded in total")
print(df_all.head())

# %%
# import matplotlib.pyplot as plt

# plt.figure(figsize=(6, 6))
# plt.plot(df["Longitude"], df["Latitude"], marker=".", linewidth=1)
# plt.xlabel("Longitude")
# plt.ylabel("Latitude")
# plt.title("Ship Trajectory")
# plt.show()


# import folium

# # Center map on average position
# m = folium.Map(location=[df["Latitude"].mean(), df["Longitude"].mean()], zoom_start=8)

# # Add trajectory as a line
# folium.PolyLine(df[["Latitude", "Longitude"]].values, color="blue", weight=2.5).add_to(m)

# # Save and open
# m.save("trajectory_map.html")
# print("✅ Map saved as trajectory_map.html")
